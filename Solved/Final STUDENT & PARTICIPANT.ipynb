# %%
#!pip install simple_salesforce

# %%
import json
from sqlalchemy import create_engine
from datetime import date
import pandas as pd
import pymysql
pymysql.install_as_MySQLdb()

# %%
# Make sure to use your own `config.py` file. Consider ensuring that these variable names are in sync
from config import sf_username, sf_password, sf_security_token
from config import remote_db_endpoint, remote_db_port
from config import remote_db_name, remote_db_user, remote_db_pwd

# %%
from simple_salesforce import Salesforce
sf = Salesforce(username=sf_username, password=sf_password, security_token=sf_security_token)

# %%
engine = create_engine(f"mysql://{remote_db_user}:{remote_db_pwd}@{remote_db_endpoint}:{remote_db_port}/{remote_db_name}")
conn = engine.connect()

# %% [markdown]
# ## Prepare ETL for the Course data

# %%
student_data = pd.read_sql("SELECT * FROM student", conn)
student_data.head()
# Out:
#    ID_Student StudentID    LastName  FirstName MiddleName BirthDate Gender
# 0          33  25004961       Moore    Heather      Alice      None      F
# 1          34  25003514      Multak      Ilana    Cecille      None      F
# 2          35  25005833     Murillo    Jessica    Dorothy      None      F
# 3          36  25002589  Romanowski     Kandra  Genevieve      None      F
# 4          37  25007185      Hoffer  Katherine   Lynnette      None      F

# %%
student_data=student_data[['ID_Student','StudentID','LastName', 'FirstName','MiddleName','BirthDate','Gender']]
student_data.head(10)
# Out:
#    ID_Student StudentID    LastName   FirstName MiddleName BirthDate Gender
# 0          33  25004961       Moore     Heather      Alice      None      F
# 1          34  25003514      Multak       Ilana    Cecille      None      F
# 2          35  25005833     Murillo     Jessica    Dorothy      None      F
# 3          36  25002589  Romanowski      Kandra  Genevieve      None      F
# 4          37  25007185      Hoffer   Katherine   Lynnette      None      F
# 5          38  25006014  Poocharoen      Pariya   Mariette      None      F
# 6          39  25007528    Mantrala  Sriharitha      Patty      None      F
# 7          40  25003778       Kelly       Carly    Raelene      None      F
# 8          41  25003605       Sraha  Clementine    Kendall      None      F
# 9          42  25002056  Abdulrahim     Jawaher     Angela      None      F

# %%
#for index, row in student_data.iterrows():
#    record = {
#        'IDStudent__c': row['ID_Student'],
#        'StudentID__c': int(row['StudentID']),
#        'LastName__c':row['LastName'],
#        'Name':row['FirstName'],
#        'MiddleName__c':row['MiddleName'],
#        'BirthDate__c':row['BirthDate'],
#        'Gender__c':row['Gender']
#    try:
#        sf.Student__c.create(record)
#    except Exception as e:
#       print(e)

# %%
student_lookup_list = []

# The `Name` column in the primary key in Salesforce objects
data = sf.query_all_iter("SELECT StudentID__c, Name FROM Student__c")
for row in data:
    rec = {
        'Student__c': row['Name'],
        'StudentID__c': row['StudentID__c']
    }
    student_lookup_list.append(rec)

# %%
student_lookup_df = pd.DataFrame(student_lookup_list)
student_lookup_df
# Out:
#      Student__c StudentID__c
# 0         Ilana     25003514
# 1        Robert     25006027
# 2         Chris     25006348
# 3          Cole     25005250
# 4        Undraa     25004097
# 5       Michael     25005443
# 6    Clementine     25003605
# 7          John     25003936
# 8     Katherine     25007185
# 9   Christopher     25002555
# 10       Kandra     25002589
# 11       Pariya     25006014
# 12         Todd     25006947
# 13        Kevin     25007334
# 14        Sarah     25004152
# 15      Jawaher     25002056
# 16         Dino     25003773
# 17        David     25002325
# 18        James     25002311
# 19       Trevor     25002876
# 20         Adit     25005284
# 21        Yasir     25007333
# 22         Pius     25006805
# 23      Heather     25004961
# 24      Jessica     25005833
# 25          Tom     25002714
# 26      Patrick     25006762
# 27   Sriharitha     25007528
# 28       Joisel     25005602
# 29        Carly     25003778

# %%
query = '''
    SELECT
        c.*
        ,s.StudentID
    FROM
        classparticipant c
        INNER JOIN student s
        ON c.ID_student = s.ID_student
'''
classparticipant_data_df = pd.read_sql(query, conn)
classparticipant_data_df.head()
# Out:
#    ID_ClassParticipant  ID_Student  ID_Class   StartDate EndDate StudentID
# 0                    1          33         1  2020-03-16    None  25004961
# 1                    2          34         1  2020-03-16    None  25003514
# 2                    3          35         1  2020-03-16    None  25005833
# 3                    4          62         1  2020-03-16    None  25007334
# 4                    5          36         1  2020-03-16    None  25002589

# %%
classparticipant_data_df.rename(columns={
    'StudentID':'StudentID__c',
    'StartDate':'Start_Date__c',
    'EndDate':'End_Date__c',
    
}, inplace=True)

classparticipant_data_df
# Out:
#     ID_ClassParticipant  ID_Student  ID_Class Start_Date__c End_Date__c  \
# 0                     1          33         1    2020-03-16        None
# 1                     2          34         1    2020-03-16        None
# 2                     3          35         1    2020-03-16        None
# 3                     4          62         1    2020-03-16        None
# 4                     5          36         1    2020-03-16        None
# 5                     6          37         1    2020-03-16        None
# 6                     7          38         1    2020-03-16        None
# 7                     8          39         1    2020-03-16        None
# 8                     9          40         1    2020-03-16        None
# 9                    10          41         1    2020-03-16        None
# 10                   11          42         1    2020-03-16        None
# 11                   12          43         1    2020-03-16        None
# 12                   13          46         1    2020-03-16        None
# 13                   14          47         1    2020-03-16        None
# 14                   15          48         1    2020-03-16        None
# 15                   16          49         1    2020-03-16        None
# 16                   17          50         1    2020-03-16        None
# 17                   18          51         1    2020-03-16        None
# 18                   20          53         1    2020-03-16        None
# 19                   21          54         1    2020-03-16        None
# 20                   22          55         1    2020-03-16        None
# 21                   23          56         1    2020-03-16        None
# 22                   24          57         1    2020-03-16        None
# 23                   25          58         1    2020-03-16        None
# 24                   26          59         1    2020-03-16        None
# 25                   27          60         1    2020-03-16        None
# 26                   28          61         1    2020-03-16        None
# 27                   29          44         1    2020-03-16        None
#
#    StudentID__c
# 0      25004961
# 1      25003514
# 2      25005833
# 3      25007334
# 4      25002589
# 5      25007185
# 6      25006014
# 7      25007528
# 8      25003778
# 9      25003605
# 10     25002056
# 11     25004152
# 12     25005602
# 13     25006805
# 14     25006947
# 15     25002714
# 16     25005284
# 17     25006348
# 18     25005250
# 19     25002325
# 20     25003773
# 21     25003936
# 22     25005443
# 23     25006762
# 24     25006027
# 25     25002876
# 26     25007333
# 27     25004097

# %%
classparticipant_data_df = pd.merge(classparticipant_data_df, student_lookup_df, how='left')
#class_data_df.drop(columns = ['ID_Class','ID_Course','CourseName','CreditHours','BootCampCourse','Course_Code__c'], inplace=True)

classparticipant_data_df.head()
# Out:
#    ID_ClassParticipant  ID_Student  ID_Class Start_Date__c End_Date__c  \
# 0                    1          33         1    2020-03-16        None
# 1                    2          34         1    2020-03-16        None
# 2                    3          35         1    2020-03-16        None
# 3                    4          62         1    2020-03-16        None
# 4                    5          36         1    2020-03-16        None
#
#   StudentID__c Student__c
# 0     25004961    Heather
# 1     25003514      Ilana
# 2     25005833    Jessica
# 3     25007334      Kevin
# 4     25002589     Kandra

# %%
classparticipant_data_df
classparticipant_data_df['Start_Date__c'] = pd.to_datetime(classparticipant_data_df['Start_Date__c']).dt.date
classparticipant_data_df['End_Date__c'] = pd.to_datetime(classparticipant_data_df['End_Date__c']).dt.date

classparticipant_data_df.head()
# Out:
#    ID_ClassParticipant  ID_Student  ID_Class Start_Date__c End_Date__c  \
# 0                    1          33         1    2020-03-16         NaT
# 1                    2          34         1    2020-03-16         NaT
# 2                    3          35         1    2020-03-16         NaT
# 3                    4          62         1    2020-03-16         NaT
# 4                    5          36         1    2020-03-16         NaT
#
#   StudentID__c Student__c
# 0     25004961    Heather
# 1     25003514      Ilana
# 2     25005833    Jessica
# 3     25007334      Kevin
# 4     25002589     Kandra

# %%
classparticipant_data_df=classparticipant_data_df[['ID_ClassParticipant','ID_Student','ID_Class','Start_Date__c',
                                       'StudentID__c','Student__c']]
classparticipant_data_df
# Out:
#     ID_ClassParticipant  ID_Student  ID_Class Start_Date__c StudentID__c  \
# 0                     1          33         1    2020-03-16     25004961
# 1                     2          34         1    2020-03-16     25003514
# 2                     3          35         1    2020-03-16     25005833
# 3                     4          62         1    2020-03-16     25007334
# 4                     5          36         1    2020-03-16     25002589
# 5                     6          37         1    2020-03-16     25007185
# 6                     7          38         1    2020-03-16     25006014
# 7                     8          39         1    2020-03-16     25007528
# 8                     9          40         1    2020-03-16     25003778
# 9                    10          41         1    2020-03-16     25003605
# 10                   11          42         1    2020-03-16     25002056
# 11                   12          43         1    2020-03-16     25004152
# 12                   13          46         1    2020-03-16     25005602
# 13                   14          47         1    2020-03-16     25006805
# 14                   15          48         1    2020-03-16     25006947
# 15                   16          49         1    2020-03-16     25002714
# 16                   17          50         1    2020-03-16     25005284
# 17                   18          51         1    2020-03-16     25006348
# 18                   20          53         1    2020-03-16     25005250
# 19                   21          54         1    2020-03-16     25002325
# 20                   22          55         1    2020-03-16     25003773
# 21                   23          56         1    2020-03-16     25003936
# 22                   24          57         1    2020-03-16     25005443
# 23                   25          58         1    2020-03-16     25006762
# 24                   26          59         1    2020-03-16     25006027
# 25                   27          60         1    2020-03-16     25002876
# 26                   28          61         1    2020-03-16     25007333
# 27                   29          44         1    2020-03-16     25004097
#
#     Student__c
# 0      Heather
# 1        Ilana
# 2      Jessica
# 3        Kevin
# 4       Kandra
# 5    Katherine
# 6       Pariya
# 7   Sriharitha
# 8        Carly
# 9   Clementine
# 10     Jawaher
# 11       Sarah
# 12      Joisel
# 13        Pius
# 14        Todd
# 15         Tom
# 16        Adit
# 17       Chris
# 18        Cole
# 19       David
# 20        Dino
# 21        John
# 22     Michael
# 23     Patrick
# 24      Robert
# 25      Trevor
# 26       Yasir
# 27      Undraa

# %%
classparticipant_data_df_records = classparticipant_data_df.to_dict(orient='records')
classparticipant_data_df_records
# Out:
# [{'ID_ClassParticipant': 1,
#   'ID_Student': 33,
#   'ID_Class': 1,
#   'Start_Date__c': datetime.date(2020, 3, 16),
#   'StudentID__c': '25004961',
#   'Student__c': 'Heather'},
#  {'ID_ClassParticipant': 2,
#   'ID_Student': 34,
#   'ID_Class': 1,
#   'Start_Date__c': datetime.date(2020, 3, 16),
#   'StudentID__c': '25003514',
#   'Student__c': 'Ilana'},
#  {'ID_ClassParticipant': 3,
#   'ID_Student': 35,
#   'ID_Class': 1,
#   'Start_Date__c': datetime.date(2020, 3, 16),
#   'StudentID__c': '25005833',
#   'Student__c': 'Jessica'},
#  {'ID_ClassParticipant': 4,
#   'ID_Student': 62,
#   'ID_Class': 1,
#   'Start_Date__c': datetime.date(2020, 3, 16),
#   'StudentID__c': '25007334',
#   'Student__c': 'Kevin'},
#  {'ID_ClassParticipant': 5,
#   'ID_Student': 36,
#   'ID_Class': 1,
#   'Start_Date__c': datetime.date(2020, 3, 16),
#   'StudentID__c': '25002589',
#   'Student__c': 'Kandra'},
#  {'ID_ClassParticipant': 6,
#   'ID_Student': 37,
#   'ID_Class': 1,
#   'Start_Date__c': datetime.date(2020, 3, 16),
#   'StudentID__c': '25007185',
#   'Student__c': 'Katherine'},
#  {'ID_ClassParticipant': 7,
#   'ID_Student': 38,
#   'ID_Class': 1,
#   'Start_Date__c': datetime.date(2020, 3, 16),
#   'StudentID__c': '25006014',
#   'Student__c': 'Pariya'},
#  {'ID_ClassParticipant': 8,
#   'ID_Student': 39,
#   'ID_Class': 1,
#   'Start_Date__c': datetime.date(2020, 3, 16),
#   'StudentID__c': '25007528',
#   'Student__c': 'Sriharitha'},
#  {'ID_ClassParticipant': 9,
#   'ID_Student': 40,
#   'ID_Class': 1,
#   'Start_Date__c': datetime.date(2020, 3, 16),
#   'StudentID__c': '25003778',
#   'Student__c': 'Carly'},
#  {'ID_ClassParticipant': 10,
#   'ID_Student': 41,
#   'ID_Class': 1,
#   'Start_Date__c': datetime.date(2020, 3, 16),
#   'StudentID__c': '25003605',
#   'Student__c': 'Clementine'},
#  {'ID_ClassParticipant': 11,
#   'ID_Student': 42,
#   'ID_Class': 1,
#   'Start_Date__c': datetime.date(2020, 3, 16),
#   'StudentID__c': '25002056',
#   'Student__c': 'Jawaher'},
#  {'ID_ClassParticipant': 12,
#   'ID_Student': 43,
#   'ID_Class': 1,
#   'Start_Date__c': datetime.date(2020, 3, 16),
#   'StudentID__c': '25004152',
#   'Student__c': 'Sarah'},
#  {'ID_ClassParticipant': 13,
#   'ID_Student': 46,
#   'ID_Class': 1,
#   'Start_Date__c': datetime.date(2020, 3, 16),
#   'StudentID__c': '25005602',
#   'Student__c': 'Joisel'},
#  {'ID_ClassParticipant': 14,
#   'ID_Student': 47,
#   'ID_Class': 1,
#   'Start_Date__c': datetime.date(2020, 3, 16),
#   'StudentID__c': '25006805',
#   'Student__c': 'Pius'},
#  {'ID_ClassParticipant': 15,
#   'ID_Student': 48,
#   'ID_Class': 1,
#   'Start_Date__c': datetime.date(2020, 3, 16),
#   'StudentID__c': '25006947',
#   'Student__c': 'Todd'},
#  {'ID_ClassParticipant': 16,
#   'ID_Student': 49,
#   'ID_Class': 1,
#   'Start_Date__c': datetime.date(2020, 3, 16),
#   'StudentID__c': '25002714',
#   'Student__c': 'Tom'},
#  {'ID_ClassParticipant': 17,
#   'ID_Student': 50,
#   'ID_Class': 1,
#   'Start_Date__c': datetime.date(2020, 3, 16),
#   'StudentID__c': '25005284',
#   'Student__c': 'Adit'},
#  {'ID_ClassParticipant': 18,
#   'ID_Student': 51,
#   'ID_Class': 1,
#   'Start_Date__c': datetime.date(2020, 3, 16),
#   'StudentID__c': '25006348',
#   'Student__c': 'Chris'},
#  {'ID_ClassParticipant': 20,
#   'ID_Student': 53,
#   'ID_Class': 1,
#   'Start_Date__c': datetime.date(2020, 3, 16),
#   'StudentID__c': '25005250',
#   'Student__c': 'Cole'},
#  {'ID_ClassParticipant': 21,
#   'ID_Student': 54,
#   'ID_Class': 1,
#   'Start_Date__c': datetime.date(2020, 3, 16),
#   'StudentID__c': '25002325',
#   'Student__c': 'David'},
#  {'ID_ClassParticipant': 22,
#   'ID_Student': 55,
#   'ID_Class': 1,
#   'Start_Date__c': datetime.date(2020, 3, 16),
#   'StudentID__c': '25003773',
#   'Student__c': 'Dino'},
#  {'ID_ClassParticipant': 23,
#   'ID_Student': 56,
#   'ID_Class': 1,
#   'Start_Date__c': datetime.date(2020, 3, 16),
#   'StudentID__c': '25003936',
#   'Student__c': 'John'},
#  {'ID_ClassParticipant': 24,
#   'ID_Student': 57,
#   'ID_Class': 1,
#   'Start_Date__c': datetime.date(2020, 3, 16),
#   'StudentID__c': '25005443',
#   'Student__c': 'Michael'},
#  {'ID_ClassParticipant': 25,
#   'ID_Student': 58,
#   'ID_Class': 1,
#   'Start_Date__c': datetime.date(2020, 3, 16),
#   'StudentID__c': '25006762',
#   'Student__c': 'Patrick'},
#  {'ID_ClassParticipant': 26,
#   'ID_Student': 59,
#   'ID_Class': 1,
#   'Start_Date__c': datetime.date(2020, 3, 16),
#   'StudentID__c': '25006027',
#   'Student__c': 'Robert'},
#  {'ID_ClassParticipant': 27,
#   'ID_Student': 60,
#   'ID_Class': 1,
#   'Start_Date__c': datetime.date(2020, 3, 16),
#   'StudentID__c': '25002876',
#   'Student__c': 'Trevor'},
#  {'ID_ClassParticipant': 28,
#   'ID_Student': 61,
#   'ID_Class': 1,
#   'Start_Date__c': datetime.date(2020, 3, 16),
#   'StudentID__c': '25007333',
#   'Student__c': 'Yasir'},
#  {'ID_ClassParticipant': 29,
#   'ID_Student': 44,
#   'ID_Class': 1,
#   'Start_Date__c': datetime.date(2020, 3, 16),
#   'StudentID__c': '25004097',
#   'Student__c': 'Undraa'}]

# %%
for rec in classparticipant_data_df_records:
 
    record = {
        'Name': rec['Student__c'],
        'Start_Date__c': str(rec['Start_Date__c']),
        
    }
    
    try:
        sf.ClassParticipant__c.create(record)
    except Exception as e:
        print(e)
# Out:
# Malformed request https://na111.salesforce.com/services/data/v42.0/sobjects/ClassParticipant__c/. Response content: [{'message': 'Required fields are missing: [ID_Student__c, ID_Class__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['ID_Student__c', 'ID_Class__c']}]
# Malformed request https://na111.salesforce.com/services/data/v42.0/sobjects/ClassParticipant__c/. Response content: [{'message': 'Required fields are missing: [ID_Student__c, ID_Class__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['ID_Student__c', 'ID_Class__c']}]
# Malformed request https://na111.salesforce.com/services/data/v42.0/sobjects/ClassParticipant__c/. Response content: [{'message': 'Required fields are missing: [ID_Student__c, ID_Class__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['ID_Student__c', 'ID_Class__c']}]
# Malformed request https://na111.salesforce.com/services/data/v42.0/sobjects/ClassParticipant__c/. Response content: [{'message': 'Required fields are missing: [ID_Student__c, ID_Class__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['ID_Student__c', 'ID_Class__c']}]
# Malformed request https://na111.salesforce.com/services/data/v42.0/sobjects/ClassParticipant__c/. Response content: [{'message': 'Required fields are missing: [ID_Student__c, ID_Class__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['ID_Student__c', 'ID_Class__c']}]
# Malformed request https://na111.salesforce.com/services/data/v42.0/sobjects/ClassParticipant__c/. Response content: [{'message': 'Required fields are missing: [ID_Student__c, ID_Class__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['ID_Student__c', 'ID_Class__c']}]
# Malformed request https://na111.salesforce.com/services/data/v42.0/sobjects/ClassParticipant__c/. Response content: [{'message': 'Required fields are missing: [ID_Student__c, ID_Class__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['ID_Student__c', 'ID_Class__c']}]
# Malformed request https://na111.salesforce.com/services/data/v42.0/sobjects/ClassParticipant__c/. Response content: [{'message': 'Required fields are missing: [ID_Student__c, ID_Class__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['ID_Student__c', 'ID_Class__c']}]
# Malformed request https://na111.salesforce.com/services/data/v42.0/sobjects/ClassParticipant__c/. Response content: [{'message': 'Required fields are missing: [ID_Student__c, ID_Class__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['ID_Student__c', 'ID_Class__c']}]
# Malformed request https://na111.salesforce.com/services/data/v42.0/sobjects/ClassParticipant__c/. Response content: [{'message': 'Required fields are missing: [ID_Student__c, ID_Class__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['ID_Student__c', 'ID_Class__c']}]
# Malformed request https://na111.salesforce.com/services/data/v42.0/sobjects/ClassParticipant__c/. Response content: [{'message': 'Required fields are missing: [ID_Student__c, ID_Class__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['ID_Student__c', 'ID_Class__c']}]
# Malformed request https://na111.salesforce.com/services/data/v42.0/sobjects/ClassParticipant__c/. Response content: [{'message': 'Required fields are missing: [ID_Student__c, ID_Class__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['ID_Student__c', 'ID_Class__c']}]
# Malformed request https://na111.salesforce.com/services/data/v42.0/sobjects/ClassParticipant__c/. Response content: [{'message': 'Required fields are missing: [ID_Student__c, ID_Class__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['ID_Student__c', 'ID_Class__c']}]
# Malformed request https://na111.salesforce.com/services/data/v42.0/sobjects/ClassParticipant__c/. Response content: [{'message': 'Required fields are missing: [ID_Student__c, ID_Class__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['ID_Student__c', 'ID_Class__c']}]
# Malformed request https://na111.salesforce.com/services/data/v42.0/sobjects/ClassParticipant__c/. Response content: [{'message': 'Required fields are missing: [ID_Student__c, ID_Class__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['ID_Student__c', 'ID_Class__c']}]
# Malformed request https://na111.salesforce.com/services/data/v42.0/sobjects/ClassParticipant__c/. Response content: [{'message': 'Required fields are missing: [ID_Student__c, ID_Class__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['ID_Student__c', 'ID_Class__c']}]
# Malformed request https://na111.salesforce.com/services/data/v42.0/sobjects/ClassParticipant__c/. Response content: [{'message': 'Required fields are missing: [ID_Student__c, ID_Class__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['ID_Student__c', 'ID_Class__c']}]
# Malformed request https://na111.salesforce.com/services/data/v42.0/sobjects/ClassParticipant__c/. Response content: [{'message': 'Required fields are missing: [ID_Student__c, ID_Class__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['ID_Student__c', 'ID_Class__c']}]
# Malformed request https://na111.salesforce.com/services/data/v42.0/sobjects/ClassParticipant__c/. Response content: [{'message': 'Required fields are missing: [ID_Student__c, ID_Class__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['ID_Student__c', 'ID_Class__c']}]
# Malformed request https://na111.salesforce.com/services/data/v42.0/sobjects/ClassParticipant__c/. Response content: [{'message': 'Required fields are missing: [ID_Student__c, ID_Class__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['ID_Student__c', 'ID_Class__c']}]
# Malformed request https://na111.salesforce.com/services/data/v42.0/sobjects/ClassParticipant__c/. Response content: [{'message': 'Required fields are missing: [ID_Student__c, ID_Class__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['ID_Student__c', 'ID_Class__c']}]
# Malformed request https://na111.salesforce.com/services/data/v42.0/sobjects/ClassParticipant__c/. Response content: [{'message': 'Required fields are missing: [ID_Student__c, ID_Class__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['ID_Student__c', 'ID_Class__c']}]
# Malformed request https://na111.salesforce.com/services/data/v42.0/sobjects/ClassParticipant__c/. Response content: [{'message': 'Required fields are missing: [ID_Student__c, ID_Class__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['ID_Student__c', 'ID_Class__c']}]
# Malformed request https://na111.salesforce.com/services/data/v42.0/sobjects/ClassParticipant__c/. Response content: [{'message': 'Required fields are missing: [ID_Student__c, ID_Class__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['ID_Student__c', 'ID_Class__c']}]
# Malformed request https://na111.salesforce.com/services/data/v42.0/sobjects/ClassParticipant__c/. Response content: [{'message': 'Required fields are missing: [ID_Student__c, ID_Class__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['ID_Student__c', 'ID_Class__c']}]
# Malformed request https://na111.salesforce.com/services/data/v42.0/sobjects/ClassParticipant__c/. Response content: [{'message': 'Required fields are missing: [ID_Student__c, ID_Class__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['ID_Student__c', 'ID_Class__c']}]
# Malformed request https://na111.salesforce.com/services/data/v42.0/sobjects/ClassParticipant__c/. Response content: [{'message': 'Required fields are missing: [ID_Student__c, ID_Class__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['ID_Student__c', 'ID_Class__c']}]
# Malformed request https://na111.salesforce.com/services/data/v42.0/sobjects/ClassParticipant__c/. Response content: [{'message': 'Required fields are missing: [ID_Student__c, ID_Class__c]', 'errorCode': 'REQUIRED_FIELD_MISSING', 'fields': ['ID_Student__c', 'ID_Class__c']}]
